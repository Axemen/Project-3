# %%
import pandas as pd

# %%
df = pd.read_csv('clean-data/Whiskey_data/Whiskey_Advocate_All_scraped_KHupdate-23 Jul (Team Style Defined).csv')
# Out:
# C:\Users\jrand\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,3,4,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.dropna(subset = ['Year \nDistrilled'], inplace = True)

# %%
weather = pd.read_csv('clean-data/Whiskey_data/master-weather.csv').drop(columns = 'Unnamed: 0')[['Year', 'Precipitation', 'Temperature', 'country']]

# %%
weather.head()
# Out:
#    Year  Precipitation  Temperature country
# 0  1970      52.835442     6.706762     USA
# 1  1971      54.006425     6.315507     USA
# 2  1972      55.370983     6.309428     USA
# 3  1973      60.521133     6.887528     USA
# 4  1974      53.775142     6.713617     USA

# %%
df = df.loc[df['Year \nDistrilled'] >= 1970]

# %%
.replace('USA', 'us')
# Out:
#        Index                                              Maker  \
# 10      11.0                                       The Macallan
# 17      18.0                                             Ardbeg
# 21      23.0                                            Lombard
# 22      24.0                                              Brora
# 23      25.0                                              Brora
# 28      30.0                                      The Glenlivet
# 29      31.0                                      Highland Park
# 31      33.0                                          Laphroaig
# 33      35.0                                         Dun Beghan
# 40      42.0                                        Compass Box
# 48      51.0                                             Ardbeg
# 50      53.0                                       The Balvenie
# 52      55.0                                           Balvenie
# 53      56.0                                          Signatory
# ...

# %%
import pandas as pd

# %%
pd.read_csv('clean-data/Whiskey_data/whisky-weather-data.csv')
