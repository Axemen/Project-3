# %%
 # Import Dependencies
import pandas as pd

# %%
csv = 'clean-data/Whiskey_data/Whisky_Review_Kurt.csv'

# %%
# Import the CSV into a pandas DataFrame
wdkurt_df = pd.read_csv(csv_path).drop(columns = 'Unnamed: 0')
wdkurt_df
# Out:
#                                            Whiskey Name  Distillery  \
# 0                        Johnnie Walker Blue Label, 40%         NaN
# 1       Black Bowmore, 1964 vintage, 42 year old, 40.5%         NaN
# 2           Bowmore 46 year old (distilled 1964), 42.9%         NaN
# 3                        Compass Box The General, 53.4%         NaN
# 4                               Chivas Regal Ultis, 40%         NaN
# 5                            Ardbeg Corryvreckan, 57.1%         NaN
# 6                    Gold Bowmore, 1964 vintage, 42.4%          NaN
# 7                           Bowmore, 40 year old, 44.8%         NaN
# 8                       The Dalmore, 50 year old, 52.8%         NaN
# 9       Glenfarclas Family Casks 1954 Cask #1260, 47.2%         NaN
# 10    The Glenlivet Cellar Collection, 1969 vintage,...         NaN
# 11    Macallan 1976 Vintage, 29 year old, cask #1135...         NaN
# 12    The Last Drop (distilled at Lochside) 1972 (ca...         NaN
# ...

# %%
wdkurt_df['ap'] = ''

# %%
for i in range(len(wdkurt_df)):
    s = wdkurt_df.iat[i, 0] 
    s = s.split(',')
    wdkurt_df.iat[i, 7] = s[-1]

# %%
wdkurt_df
# Out:
#                                            Whiskey Name  Distillery  \
# 0                        Johnnie Walker Blue Label, 40%         NaN
# 1       Black Bowmore, 1964 vintage, 42 year old, 40.5%         NaN
# 2           Bowmore 46 year old (distilled 1964), 42.9%         NaN
# 3                        Compass Box The General, 53.4%         NaN
# 4                               Chivas Regal Ultis, 40%         NaN
# 5                            Ardbeg Corryvreckan, 57.1%         NaN
# 6                    Gold Bowmore, 1964 vintage, 42.4%          NaN
# 7                           Bowmore, 40 year old, 44.8%         NaN
# 8                       The Dalmore, 50 year old, 52.8%         NaN
# 9       Glenfarclas Family Casks 1954 Cask #1260, 47.2%         NaN
# 10    The Glenlivet Cellar Collection, 1969 vintage,...         NaN
# 11    Macallan 1976 Vintage, 29 year old, cask #1135...         NaN
# 12    The Last Drop (distilled at Lochside) 1972 (ca...         NaN
# ...

# %%
wdkurt_df['label'] = ''

# %%
for i in range(len(wdkurt_df)):
    s = wdkurt_df.iat[i, 0] 
    s = s.split(',')
    wdkurt_df.iat[i, 8] = s[0]

# %%
wdkurt_df
# Out:
#                                            Whiskey Name  Distillery  \
# 0                        Johnnie Walker Blue Label, 40%         NaN
# 1       Black Bowmore, 1964 vintage, 42 year old, 40.5%         NaN
# 2           Bowmore 46 year old (distilled 1964), 42.9%         NaN
# 3                        Compass Box The General, 53.4%         NaN
# 4                               Chivas Regal Ultis, 40%         NaN
# 5                            Ardbeg Corryvreckan, 57.1%         NaN
# 6                    Gold Bowmore, 1964 vintage, 42.4%          NaN
# 7                           Bowmore, 40 year old, 44.8%         NaN
# 8                       The Dalmore, 50 year old, 52.8%         NaN
# 9       Glenfarclas Family Casks 1954 Cask #1260, 47.2%         NaN
# 10    The Glenlivet Cellar Collection, 1969 vintage,...         NaN
# 11    Macallan 1976 Vintage, 29 year old, cask #1135...         NaN
# 12    The Last Drop (distilled at Lochside) 1972 (ca...         NaN
# ...
