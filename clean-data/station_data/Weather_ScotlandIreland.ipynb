# %%
import pandas as pd

# %% [markdown]
# READ IN STATIONS

# %%
df = pd.read_csv('clean-data/station_data/concated_stations.csv')

# %%
df.head()
# Out:
#         Day  Max Temperature  Min Temperature  Precipitation           id
# 0  1/1/1973             11.1             10.0            9.3  EI000003953
# 1  1/2/1973             11.9              9.8            3.3  EI000003953
# 2  1/3/1973             11.2              8.8            2.0  EI000003953
# 3  1/4/1973             11.4              9.7            0.0  EI000003953
# 4  1/5/1973             11.1              6.6            0.0  EI000003953

# %%
list(df)
# Out:
# ['Day', 'Max Temperature', 'Min Temperature', 'Precipitation', 'id']

# %% [markdown]
# GET NAMES OF IDS + COUNTRIES

# %%
stations={}
stations['id']=df['id'].unique()
stations['id']
# Out:
# array(['EI000003953', 'EI000003969', 'EIE00107762', 'EIE00107808',
#        'EIM00003955', 'EIM00003962', nan, 'EIM00003976', 'UK000003162',
#        'UK000070765', 'UKM00003017', 'UKM00003066', 'UKM00003091',
#        'UKM00003171', 'UKM00003917'], dtype=object)

# %%
countries = pd.read_csv('clean-data/station_data/station-ids.csv')

# %%
list(countries)
# Out:
# ['station_id',
#  'station_name',
#  'lat',
#  'long',
#  'state',
#  'country',
#  'units',
#  'elevation(m)']

# %%
stations['country']=[]
for i in stations:
    for j in range(len(countries)):
        if i == countries['station_id'][j]:
            stations['country'].append(countries['country'][j])

# %%
stations
# Out:
# {'id': array(['EI000003953', 'EI000003969', 'EIE00107762', 'EIE00107808',
#         'EIM00003955', 'EIM00003962', nan, 'EIM00003976', 'UK000003162',
#         'UK000070765', 'UKM00003017', 'UKM00003066', 'UKM00003091',
#         'UKM00003171', 'UKM00003917'], dtype=object), 'country': []}

# %% [markdown]
# GET YEARS ARRAY

# %%
years = []
for i in range(len(df)):
    year = df['Day'][i][-4:]
    if year not in years: 
        years.append(year)

# %%
years
# Out:
# ['1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019']

# %% [markdown]
# FIND AVERAGE BY YEAR AND STATION

# %%
df.head()
# Out:
#         Day  Max Temperature  Min Temperature  Precipitation           id
# 0  1/1/1973             11.1             10.0            9.3  EI000003953
# 1  1/2/1973             11.9              9.8            3.3  EI000003953
# 2  1/3/1973             11.2              8.8            2.0  EI000003953
# 3  1/4/1973             11.4              9.7            0.0  EI000003953
# 4  1/5/1973             11.1              6.6            0.0  EI000003953

# %%
for i in range(len(df)):
    df.iat[i, 0] = df.iat[i, 0].split('/')[-1]

# %%
df.groupby('Day').mean()
# Out:
#       Max Temperature  Min Temperature  Precipitation
# Day
# 1973        12.263806         5.257441       2.454558
# 1974        12.118335         5.282281       2.807041
# 1975        12.754090         5.623249       2.266248
# 1976        12.507556         5.719456       2.512850
# 1977        12.242508         5.570935       2.847908
# 1978        12.205441         5.975528       2.730645
# 1979        11.472482         5.040128       2.930052
# 1980        12.044991         5.873619       2.955688
# 1981        12.189861         5.611928       2.840800
# 1982        12.930045         5.810115       3.424790
# 1983        12.903397         5.958614       2.839791
# 1984        13.018521         5.663190       3.107118
# 1985        11.901905         5.316959       3.409256
# 1986        11.712122         4.932595       3.267492
# 1987        12.132567         5.528822       2.936852
# 1988        12.553896         5.947758       3.298799
# ...

# %%
df.to_csv("clean-data/station_data/avg_")
